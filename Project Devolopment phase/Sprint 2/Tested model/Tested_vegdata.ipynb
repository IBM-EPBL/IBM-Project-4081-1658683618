# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_dir=r'/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/VGEGE H5/vegedata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Potato___healthy/a8d687be-3777-403f-bae7-5c8c19340b3f___RS_HL 1738.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FC410B97F90>

# %%
img=image.load_img(r"/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Potato___healthy/a8d687be-3777-403f-bae7-5c8c19340b3f___RS_HL 1738.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 89ms/step
# 'Potato___healthy'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 308s 6s/step - loss: 9.6598 - accuracy: 0.0210
# [9.6598482131958, 0.020999999716877937]
