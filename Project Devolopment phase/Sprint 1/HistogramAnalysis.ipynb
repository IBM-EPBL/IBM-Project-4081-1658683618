# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
I = imread('/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Pepper,_bell___healthy/b704a626-1cb5-47a8-a8b5-e6df7b2a895d___JR_HL 8096.JPG')
J = imread('/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Pepper,_bell___healthy/f6f43f0f-592b-4e5a-9a34-73856a4a8571___JR_HL 5988.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread('/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/06dad629-8898-4e90-bd0d-f1b34350b7a1___RS_HL 7387.JPG')
mask = imread('/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/06dad629-8898-4e90-bd0d-f1b34350b7a1___RS_HL 7387.JPG')

print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 0 255
# 0 255

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)
