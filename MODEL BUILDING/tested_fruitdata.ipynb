# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_dir=r'/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/TRAIN H5/fruitdata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/train/Corn_(maize)___Northern_Leaf_Blight/0079c731-80f5-4fea-b6a2-4ff23a7ce139___RS_NLB 4121.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F2F85B9FBD0>

# %%
img=image.load_img(r"/content/drive/MyDrive/NALAYATHIRAN_PLANT/DATASET/Dataset Plant Disease/fruit-dataset/fruit-dataset/train/Corn_(maize)___Northern_Leaf_Blight/0079c731-80f5-4fea-b6a2-4ff23a7ce139___RS_NLB 4121.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 'Corn_(maize)___Northern_Leaf_Blight'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 43s 874ms/step - loss: 331.2423 - accuracy: 0.7020
# [331.2423095703125, 0.7020000219345093]
